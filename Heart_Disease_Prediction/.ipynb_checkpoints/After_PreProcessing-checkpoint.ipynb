# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df = df.drop(columns="sex",axis=1)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt=".2g")
# Out:
# <AxesSubplot:>

# %%
target =df["target"]
features = df.drop("target", axis=1)

# %% [markdown]
# # FEATURE SELECTION METHOD = PCA

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(features)

# Transform the features using PCA
transformed_features = pca.transform(features)

# Print explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratio:")
print(explained_variance_ratio)

# Print transformed features
print("Transformed Features:")
print(transformed_features)
# Out:
# Explained Variance Ratio:
# [7.47606844e-01 1.50379182e-01 8.46018458e-02 1.62165899e-02
#  3.82102762e-04 2.81070336e-04 2.28642185e-04 9.53806548e-05
#  7.55507497e-05 5.81206901e-05 4.31122574e-05 3.15583783e-05]
# Transformed Features:
# [[-1.22668034e+01  2.87362846e+00  1.49701845e+01 ...  6.55133311e-01
#    7.10092005e-02  5.72167950e-01]
#  [ 2.69069384e+00 -3.98716464e+01  8.78315904e-01 ...  7.03120755e-01
#   -2.44650620e-01 -1.01714708e-01]
#  [-4.29515077e+01 -2.36362106e+01  1.75868204e+00 ... -8.46498968e-01
#   -1.98890932e-01  9.14081800e-03]
#  ...
#  [-5.19633302e+01  1.33236648e+01  1.54870401e+01 ... -8.45236151e-02
#   -3.94754558e-01  9.59641937e-01]
#  [-1.14755585e+02  3.64351478e+01  1.27791987e-01 ...  2.96704776e-01
#    2.53532611e-01 -1.72426804e-01]
#  [-1.03973866e+01 -2.33018417e+01  2.39059153e+00 ...  5.76724428e-01
#   -2.66643795e-01 -2.81943429e-01]]

# %%
# Set the threshold value
threshold = 0.99996  # Choose a value between 0 and 1

# Calculate cumulative explained variance
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

# Determine the number of components to select based on the threshold
num_components = np.argmax(cumulative_variance_ratio >= threshold) + 1

# Select the column names corresponding to the selected components
selected_column_names = df.columns[:num_components]

selected_components = transformed_features[:, :num_components]

# Create a new DataFrame with selected components and column names
selected_df = pd.DataFrame(data=selected_components, columns=selected_column_names)

# Print the selected DataFrame
print("Selected Components:")
print(selected_df)
# Out:
# Selected Components:
#             age         cp   trestbps       chol       fbs   restecg  \
# 0    -12.266803   2.873628  14.970184   6.894449 -0.083428  2.674820
# 1      2.690694 -39.871646   0.878316 -10.582041  2.599172  2.448853
# 2    -42.951508 -23.636211   1.758682  -7.790157  0.501803  0.269692
# 3    -10.944219 -28.438281  -7.043825   8.329671  0.054168  0.141247
# 4    106.978003 -15.874135 -14.862055   3.221550 -0.201562 -0.520316
# ..          ...        ...        ...        ...       ...       ...
# 298   -4.555337  27.490733   5.373708  -2.984945 -1.116417 -0.737077
# 299   16.428611  12.921408 -25.582450  -9.395895 -0.846487  2.133923
# 300  -51.963330  13.323665  15.487040  11.638668  2.480808 -0.095999
# 301 -114.755585  36.435148   0.127792   0.511746  0.154927 -0.743571
# 302  -10.397387 -23.301842   2.390592   7.180197 -0.106469 -0.570767
#
#       thalach     exang   oldpeak     slope        ca
# 0    0.242817  1.339913 -0.648979  0.655133  0.071009
# 1   -0.211869  0.552380  0.308037  0.703121 -0.244651
# 2   -0.399673  0.333587 -0.319549 -0.846499 -0.198891
# 3   -0.692550  0.154311  0.571519 -0.260299 -0.031576
# 4   -1.164699  0.218561  0.653623 -0.122501  0.708068
# ..        ...       ...       ...       ...       ...
# 298 -1.056202 -0.797391  0.172862  0.643907  0.256639
# 299  1.014527 -0.934827  0.185993  0.295670 -0.249532
# 300 -0.131860 -0.284263  0.564492 -0.084524 -0.394755
# 301 -0.411988 -0.733783  0.164075  0.296705  0.253533
# 302  0.078614  0.391837 -0.697916  0.576724 -0.266644
#
# [303 rows x 11 columns]

# %%
df = pd.concat([selected_df, df[['target']]], axis=1)
df.head()
# Out:
#           age         cp   trestbps       chol       fbs   restecg   thalach  \
# 0  -12.266803   2.873628  14.970184   6.894449 -0.083428  2.674820  0.242817
# 1    2.690694 -39.871646   0.878316 -10.582041  2.599172  2.448853 -0.211869
# 2  -42.951508 -23.636211   1.758682  -7.790157  0.501803  0.269692 -0.399673
# 3  -10.944219 -28.438281  -7.043825   8.329671  0.054168  0.141247 -0.692550
# 4  106.978003 -15.874135 -14.862055   3.221550 -0.201562 -0.520316 -1.164699
#
#       exang   oldpeak     slope        ca  target
# 0  1.339913 -0.648979  0.655133  0.071009       1
# 1  0.552380  0.308037  0.703121 -0.244651       1
# 2  0.333587 -0.319549 -0.846499 -0.198891       1
# 3  0.154311  0.571519 -0.260299 -0.031576       1
# 4  0.218561  0.653623 -0.122501  0.708068       1

# %%
X = df.drop(columns="target",axis=1)
Y = df["target"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standardized_X = scaler.fit_transform(X)

X = standardized_X
Y = df["target"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.20, stratify=Y,random_state=42)
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (303, 11) (242, 11) (61, 11)

# %%
from sklearn import svm

svm_classifier = svm.SVC(kernel="linear")
svm_classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression()
lr_classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

#SVM
X_train_prediction_SVM = svm_classifier.predict(X_train)
train_acc_SVM = accuracy_score(X_train_prediction_SVM,Y_train)

X_test_prediction_SVM = svm_classifier.predict(X_test)
test_acc_SVM = accuracy_score(X_test_prediction_SVM,Y_test)

#Logistic Regression
X_train_prediction_lr = lr_classifier.predict(X_train)
train_acc_lr = accuracy_score(X_train_prediction_lr,Y_train)

X_test_prediction_lr = lr_classifier.predict(X_test)
test_acc_lr = accuracy_score(X_test_prediction_lr,Y_test)

#Decision Tree
X_train_prediction_dt = dt_classifier.predict(X_train)
train_acc_dt = accuracy_score(X_train_prediction_dt,Y_train)

X_test_prediction_dt = dt_classifier.predict(X_test)
test_acc_dt = accuracy_score(X_test_prediction_dt,Y_test)

#Random Forest
X_train_prediction_rf = rf_classifier.predict(X_train)
train_acc_rf = accuracy_score(X_train_prediction_rf,Y_train)

X_test_prediction_rf = rf_classifier.predict(X_test)
test_acc_rf = accuracy_score(X_test_prediction_rf,Y_test)

print("Training Accuracy:-\n1. SVM\t\t\t",train_acc_SVM,"\n2. Logistic Regression\t",train_acc_lr,"\n3. Decision Tree\t",train_acc_dt,"\n4. Random Forest\t",train_acc_rf)
print("\n\nTest Accuracy:-\n1. SVM\t\t\t",test_acc_SVM,"\n2. Logistic Regression\t",test_acc_lr,"\n3. Decision Tree\t",test_acc_dt,"\n4. Random Forest\t",test_acc_rf)
# Out:
# Training Accuracy:-
# 1. SVM			 0.8553719008264463
# 2. Logistic Regression	 0.8429752066115702
# 3. Decision Tree	 1.0
# 4. Random Forest	 1.0
#
#
# Test Accuracy:-
# 1. SVM			 0.8032786885245902
# 2. Logistic Regression	 0.7704918032786885
# 3. Decision Tree	 0.819672131147541
# 4. Random Forest	 0.7540983606557377

# %%
algo_names = ["SVM","LR","DT","RF"]
train_acc = [round(train_acc_SVM,3),round(train_acc_lr,3),round(train_acc_dt,3),round(train_acc_rf,3)]
test_acc =[round(test_acc_SVM,3),round(test_acc_lr,3),round(test_acc_dt,3),round(test_acc_rf,3)]
X_axis = np.arange(len(algo_names))

plt.figure(figsize=(5,5))
bar_width = 0.3
plt.bar(algo_names, train_acc, width=bar_width, align='center', label='train_acc')
plt.bar([i + bar_width for i in range(len(algo_names))], test_acc, width=bar_width, align='center', label='test_acc')

for i, model in enumerate(algo_names):
    plt.text(i, train_acc[i], str(train_acc[i]), ha='center', va='bottom', rotation=90)
    plt.text(i + bar_width, test_acc[i], str(test_acc[i]), ha='center', va='bottom', rotation=90)

plt.xticks(X_axis, algo_names)
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy of Different Models")
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.ylim(top=max(max(train_acc), max(test_acc)) + 0.12)
plt.grid(visible=False)
plt.show()

# %%
import pickle

filename = "heart_model.sav"
pickle.dump(svm_classifier,open(filename,"wb"))

# %%
loaded_model = pickle.load(open("heart_model.sav","rb"))
